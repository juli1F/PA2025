# %% [markdown]
# <a href="https://colab.research.google.com/github/juli1F/PA2025/blob/main/termo/jogo_termo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

tentativas = 6

palavras = ['roxas', 'pedro', 'lucas', 'bruno']

palavra = random.choice(palavras)

letras = []
for letra in palavra:
    letras.append(letra)

qtd_letras = len(letras)

(f'Tente adivinhar um nome com {qtd_letras} letras!')

while tentativas > 0 :
    chute = input(f'\nVocê tem {tentativas} tentativas. Digite um nome com {qtd_letras} letras: ').lower()

    qtd_chute = len(chute)

    while qtd_chute != qtd_letras:
        chute = input(f'\nVocê tem {tentativas} tentativas. Digite um nome com {qtd_letras} letras: ').lower()
        qtd_chute = len(chute)


    resultado = []


    for i in range(qtd_letras):
        if chute[i] == letras[i]:

            resultado.append(chute[i].upper())

        elif chute[i] in letras:

            resultado.append(chute[i])
        else:

            resultado.append('_')
    tentativas -=1

    print('Resultado: ', ' '.join(resultado))

    if chute == palavra:
        print('Parabéns! Você acertou a palavra!')

        break

    if tentativas == 0:
        print(f'Você perdeu! A palavra correta era: {palavra}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1185889555.py in <cell line: 0>()
#      16
#      17 while tentativas > 0 :
# ---> 18     chute = input(f'\nVocê tem {tentativas} tentativas. Digite um nome com {qtd_letras} letras: ').lower()
#      19
#      20     qtd_chute = len(chute)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
