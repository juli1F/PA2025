# %% [markdown]
# <a href="https://colab.research.google.com/github/juli1F/PA2025/blob/main/listas_tuplas_dicionario_string/Exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercício 1: Manipulação de Listas
#
# Defina uma lista com 5 nomes de cidades.
# Adicione uma nova cidade ao final da lista.
# Remova a segunda cidade da lista.
# Imprima a lista resultante.

# %%
# seu código aqui...
cidades= ["São Paulo", "Rio de Janeiro", "Belo Horizonte", "Porto Alegre", "Brasília"]
cidades.append("João Pessoa")
cidades.remove("Belo Horizonte")
print(cidades)
# Out:
# ['São Paulo', 'Rio de Janeiro', 'Porto Alegre', 'Brasília', 'João Pessoa']

# %% [markdown]
# #Exercício 2: Operações com Tuplas
# Defina uma tupla com 4 cores.
# Crie uma nova tupla que seja a concatenação da tupla original com outra contendo mais 2 cores.
# Imprima a nova tupla

# %%
# seu código aqui...
cores= ("amarelo", "roxo", "rosa", "verde")
cores_atuais= cores + ("azul",)
cores_maisatuais= cores_atuais + ("laranja", )
print(cores_maisatuais)
# Out:
# ('amarelo', 'roxo', 'rosa', 'verde', 'azul', 'laranja')

# %% [markdown]
# Exercício 3: Dicionários Simples
# Crie um dicionário para representar um aluno, contendo "nome", "idade" e "curso".
#
# Atualize a idade do aluno.
# Adicione uma nova chave "nota" com um valor.
# Imprima o dicionário atualizado

# %%
# seu código aqui...
aluno= {
    "nome": "André",
    "idade": 20,
    "curso": "medicina"
}
aluno["idade"]= 21
aluno["nota"]= "9"
print(aluno)
# Out:
# {'nome': 'André', 'idade': 21, 'curso': 'medicina', 'nota': '9'}

# %% [markdown]
# Exercício 4: Listas e Dicionários
# Crie uma lista de dicionários, onde cada dicionário representa um produto com as chaves "nome" e "preço".
# Adicione um novo produto à lista.
# Atualize o preço do primeiro produto na lista.
# Imprima a lista resultante.

# %%
# seu código aqui...
lista= {"anel":40, "colar":50, "pulseira": 30}
lista["brinco"]= 20
lista["anel"]= 50
print(lista)
# Out:
# {'anel': 50, 'colar': 50, 'pulseira': 30, 'brinco': 20}

# %% [markdown]
# Exercício 5: Analisando uma Lista de Tuplas
# Crie uma lista de tuplas, onde cada tupla contém um par (nome, idade).
# Encontre e imprima o nome da pessoa mais velha.
# Encontre e imprima a idade média das pessoas.

# %%
nome_id = [("José", 30), ("Ana", 25), ("Maria", 19), ("Antonio", 60)]

# %%
nome_id[0][1]
# Out:
# 30

# %%
mais_velho= 0
pessoamais_velha = ""

if (nome_id[0][1])> mais_velho:
  mais_velho= nome_id[0][1]
  pessoamais_velha = nome_id[0][0]

# %%
if (nome_id[1][1])> mais_velho:
  mais_velho= nome_id[1][1]
  pessoamais_velha = nome_id[1][0]

# %%
if (nome_id[2][1])> mais_velho:
  mais_velho= nome_id[2][1]
  pessoamais_velha = nome_id[2][0]

# %%
if (nome_id[3][1])> mais_velho:
  mais_velho= nome_id[3][1]
  pessoamais_velha = nome_id[3][0]

# %%
print("A pessoa mais velha é", pessoamais_velha)
# Out:
# A pessoa mais velha é Antonio

# %%
média_idade = (nome_id[0][1]) + (nome_id[1][1]) + (nome_id[2][1]) + (nome_id[3][1])/4

# %%
print("A média das pessoas são", média_idade)
# Out:
# A média das pessoas são 89.0

# %% [markdown]
# #Manipulação de String

# %%
# 1 - Use o método len para imprimir o comprimento da string.
x = "Hello World"
print(len(x))
# Out:
# 11

# %%
# 2 - Obtenha o primeiro caractere da string txt.
txt = "Hello World"
print(txt)
txt[0]
# Out:
# Hello World
# 'H'

# %%
# 3 - Obtenha os caracteres do índice 2 ao índice 4 ( llo).
txt = "Hello World"
txt[2:5]
# Out:
# 'llo'

# %%
# 4 - Converta o valor de txt para maiúsculas.
txt = "Hello World"
txt_maiuscula= txt.upper()
print(txt_maiuscula)
# Out:
# HELLO WORLD

# %%
# 5 - Conte quantas vezes aparece a palavra "de" na string abaixo
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
txt.count('de')
# Out:
# 3

# %%
# 6 - Separe a frase abaixo toda vez que encontrar um vírgula
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
txt.split(',')
# Out:
# ['Eu gosto de vijar',
#  ' tomar vinho',
#  ' de estudar estudar programação',
#  ' de estudar Pyhon']

# %%
#7 - Peça ao usuário uma frase e substitua todas as ocorrências de espaço por “#”.
frase= input("Digite uma frase: ")
frase= frase.replace(" ", "#")
print(frase)
# Out:
# Digite uma frase: Eu gosto de comer
# Eu#gosto#de#comer

# %%
# 8 - Faça um programa que retorne True se duas strings lidas do teclado são palíndromas mútuas, ou seja, se uma é igual à outra quando lida de traz para frente ou False, se não forem.
# Por exemplo: amor e roma

palavra1= input("Digite uma palavra: ").lower()
palavra2= input("Digite uma palavra: ").lower()

mutua = palavra1 == palavra2[::-1]
palidroma1 = palavra1 == palavra1[::-1]
palidroma2 = palavra2 == palavra2[::-1]

print("As palavras são mutuas?", mutua)
print("A primeira palavra é palidroma com ela mesma?", palidroma1)
print("A segunda palavra é palidroma com ela mesma?", palidroma2)
# Out:
# Digite uma palavra: osso
# Digite uma palavra: ana
# As palavras são mutuas? False
# A primeira palavra é palidroma com ela mesma? True
# A segunda palavra é palidroma com ela mesma? True

# %%
# 9- Faça um programa que leia o nome do usuário e mostre o nome de traz para frente, utilizando somente letras maiúsculas.

nome = input("Digite um nome: ")
nome_mauisculo = nome.upper()

print("Esse nome fica assim invertido:", nome[::-1])
